# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import models
from keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from keras.optimizers import Adam, SGD

# Image data generator setup
image_datagen = ImageDataGenerator(rescale=1./255, dtype='float32', validation_split=0.2)

# Training set
train_set = image_datagen.flow_from_directory('datasets/Train/',
                                              target_size=(28, 28),
                                              batch_size=1,
                                              class_mode='categorical',
                                              subset='training'
                                              )

# Validation set
validation_set = image_datagen.flow_from_directory('datasets/Train/',
                                                   target_size=(28, 28),
                                                   batch_size=1,
                                                   class_mode='categorical',
                                                   subset='validation'
                                                   )

# Test set
test_set = image_datagen.flow_from_directory('datasets/Test/',
                                             target_size=(28, 28),
                                             batch_size=1,
                                             class_mode='categorical',
                                             )

# Define the model
model = models.Sequential()
model.add(Conv2D(filters=16, kernel_size=(5, 5), padding='same', input_shape=(28, 28, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(filters=36, kernel_size=(5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))
model.add(Flatten())
model.add(Dense(16, activation='softmax'))
model.summary()

# Define the optimizer and loss function
learning_rate = 0.0003
sgd = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

# Train the model
history = model.fit(train_set, validation_data=validation_set, batch_size=200, epochs=50)

# Accuracy and loss for the training and validation sets
print("Accuracy_Train: ", str(history.history['accuracy'][-1]))
print("Accuracy_Val: ", str(history.history['val_accuracy'][-1]))
print("Loss_Train: ", str(history.history['loss'][-1]))
print("Loss_Val: ", str(history.history['val_loss'][-1]))

# Accuracy and loss for the test set
test_loss, test_acc = model.evaluate(test_set)
print(' ')
print('Accuracy for Testset:', test_acc)
print(' ')

# Plot the training and validation loss curves
plt.plot(history.history['loss'])
plt.plot(history.history["val_loss"])
plt.title('Train Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
plt.clf()

# Plot the training and validation accuracy curves
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Found 973 images belonging to 16 classes.
# Found 236 images belonging to 16 classes.
# Found 1300 images belonging to 16 classes.
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_37"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_42 (Conv2D)              │ (None, 28, 28, 16)     │         1,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# # Data Augmentation

# %%
import os
from PIL import Image

def flip_images_in_folder(input_folder, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all files in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith('.jpg'):
            img_path = os.path.join(input_folder, filename)
            img = Image.open(img_path)

            # Convert the image to RGB mode if it's in RGBA mode
            if img.mode == 'RGBA':
                img = img.convert('RGB')

            # Flip the image vertically
            # flipped_img = img.transpose(Image.FLIP_TOP_BOTTOM)
            # Flip the image horizontally
            flipped_img = img.transpose(Image.FLIP_LEFT_RIGHT)

            # Save the flipped image to the output folder
            flipped_img_path = os.path.join(output_folder, f"left_right_{os.path.splitext(filename)[0]}.jpg")
            flipped_img.save(flipped_img_path)

# Define input and output folders
input_folder = "datasets/Train/A"
output_folder = "flip/A"

# Execute the function
flip_images_in_folder(input_folder, output_folder)
